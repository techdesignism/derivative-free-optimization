# %%
from numpy import *
import matplotlib.pyplot as plt
from obj_funcs_lib import *


import numpy as np
np.set_printoptions(precision=2)
import nevergrad as ng
from obj_funcs_lib import *


import time

# %%
with open("valid_opt_list_rosenbrock.txt", "r") as f:
    filtered_optimizers = [line.strip() for line in f if line.strip()]


all_optimizers = list(ng.optimizers.registry.keys())

filtered_all_optimizers = [name for name in all_optimizers if name in filtered_optimizers]

print(len(filtered_all_optimizers))
filtered_all_optimizers
# Out:
# 11
# ['TinySQP',
#  'DS4',
#  'DS5',
#  'ChainMetaModelDSSQP',
#  'NgIoh16',
#  'NgIoh21',
#  'NgIoh20',
#  'NgIoh18',
#  'NgIoh10',
#  'NgIoh8',
#  'NgIoh13b']

# %%
dim = 3
start_point = [200] * dim

current_obj = rosenbrock
i = 0
for opt_name in filtered_all_optimizers:
    print(i)

    try:
        start_time = time.time()
        optimizer_cls = ng.optimizers.registry[opt_name]
        optimizer = optimizer_cls(parametrization=ng.p.Array(init=start_point), budget=5000)
        recommendation = optimizer.minimize(lambda x: current_obj(x))
        best_value = current_obj(recommendation.value)
        elapsed = time.time() - start_time
        print(f"Best value for {opt_name}: {best_value}")
        print(f"Time taken for {opt_name}: {elapsed:.2f} seconds")
        print('='*20)
    except Exception as e:
        print(e)
        pass
    i += 1
# Out:
# 0
# Best value for TinySQP: [2.45e-17]
# Time taken for TinySQP: 1.95 seconds
# ====================
# 1
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for DS4: [3.61e-11]
# Time taken for DS4: 17.06 seconds
# ====================
# 2
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 13
#      11 optimizer_cls = ng.optimizers.registry[opt_name]
#      12 optimizer = optimizer_cls(parametrization=ng.p.Array(init=start_point), budget=5000)
# ---> 13 recommendation = optimizer.minimize(lambda x: current_obj(x))
#      14 best_value = current_obj(recommendation.value)
#      15 elapsed = time.time() - start_time
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\base.py:723, in Optimizer.minimize(self, objective_function, executor, batch_mode, verbosity, constraint_violation, max_time)
#     721 for _ in range(new_sugg):
#     722     try:
# --> 723         args = self.ask()
#     724     except errors.NevergradEarlyStopping:
#     725         remaining_budget = 0
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\base.py:508, in Optimizer.ask(self)
#     505 self.parametrization.tabu_fails = 0
#     507 if self.skip_constraints and not self._suggestions:
# --> 508     candidate = self._internal_ask_candidate()
#     509     is_suggestion = False
#     510 else:
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\optimizerlib.py:3410, in _Chain._internal_ask_candidate(self)
#    3407         break
#    3408 # if we are over budget, then use the last one...
# -> 3410 candidate = opt.ask()
#    3411 candidate._meta["optim_index"] = chosen_index
#    3412 return candidate
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\base.py:508, in Optimizer.ask(self)
#     505 self.parametrization.tabu_fails = 0
#     507 if self.skip_constraints and not self._suggestions:
# --> 508     candidate = self._internal_ask_candidate()
#     509     is_suggestion = False
#     510 else:
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\optimizerlib.py:2180, in _MetaModel._internal_ask_candidate(self)
#    2178         candidate = self._optim.ask()
#    2179 else:
# -> 2180     candidate = self._optim.ask()
#    2181 return candidate
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\base.py:508, in Optimizer.ask(self)
#     505 self.parametrization.tabu_fails = 0
#     507 if self.skip_constraints and not self._suggestions:
# --> 508     candidate = self._internal_ask_candidate()
#     509     is_suggestion = False
#     510 else:
#
# File c:\Users\Benny\anaconda3\Lib\site-packages\nevergrad\optimization\recaster.py:268, in SequentialRecastOptimizer._internal_ask_candidate(self)
#     266 alive = self._messaging_thread.is_alive()
#     267 if alive:
# --> 268     point = self._messaging_thread.messages_ask.get()
#     269     if isinstance(point, Exception):
#     270         raise point
#
# File c:\Users\Benny\anaconda3\Lib\queue.py:199, in Queue.get(self, block, timeout)
#     197 elif timeout is None:
#     198     while not self._qsize():
# --> 199         self.not_empty.wait()
#     200         if self.is_shutdown and not self._qsize():
#     201             raise ShutDown
#
# File c:\Users\Benny\anaconda3\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %%
dim = 3
start_point = [200] * dim

current_obj = rastrigin
i = 0
for opt_name in filtered_all_optimizers:
    print(i)

    try:
        start_time = time.time()
        optimizer_cls = ng.optimizers.registry[opt_name]
        optimizer = optimizer_cls(parametrization=ng.p.Array(init=start_point), budget=5000)
        recommendation = optimizer.minimize(lambda x: current_obj(x))
        best_value = current_obj(recommendation.value)
        elapsed = time.time() - start_time
        print(f"Best value for {opt_name}: {best_value}")
        print(f"Time taken for {opt_name}: {elapsed:.2f} seconds")
        print('='*20)
    except Exception as e:
        print(e)
        pass
    i += 1
# Out:
# 0
# Best value for TinySQP: 11.939493571696573
# Time taken for TinySQP: 1.90 seconds
# ====================
# 1
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for DS4: 5.969749304740667
# Time taken for DS4: 8.33 seconds
# ====================
# 2
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for DS5: 0.9949590570932898
# Time taken for DS5: 6.66 seconds
# ====================
# 3
# Best value for ChainMetaModelDSSQP: 9.949560298580298
# Time taken for ChainMetaModelDSSQP: 4.66 seconds
# ====================
# 4
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh16: 0.9949590570932898
# Time taken for NgIoh16: 6.00 seconds
# ====================
# 5
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh21: 1.9899181141865796
# Time taken for NgIoh21: 11.79 seconds
# ====================
# 6
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh20: 1.9899181141865796
# Time taken for NgIoh20: 10.96 seconds
# ====================
# 7
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh18: 0.0
# Time taken for NgIoh18: 6.87 seconds
# ====================
# 8
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh10: 0.0
# Time taken for NgIoh10: 14.40 seconds
# ====================
# 9
# Best value for NgIoh8: 1.5440502246566652
# Time taken for NgIoh8: 3.47 seconds
# ====================
# 10
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh13b: 0.9949590570933147
# Time taken for NgIoh13b: 8.95 seconds
# ====================

# %%
dim = 3
start_point = [200] * dim

current_obj = ackley
i = 0
for opt_name in filtered_all_optimizers:
    print(i)

    try:
        start_time = time.time()
        optimizer_cls = ng.optimizers.registry[opt_name]
        optimizer = optimizer_cls(parametrization=ng.p.Array(init=start_point), budget=5000)
        recommendation = optimizer.minimize(lambda x: current_obj(x))
        best_value = current_obj(recommendation.value)
        elapsed = time.time() - start_time
        print(f"Best value for {opt_name}: {best_value}")
        print(f"Time taken for {opt_name}: {elapsed:.2f} seconds")
        print('='*20)
    except Exception as e:
        print(e)
        pass
    i += 1
# Out:
# 0
# Best value for TinySQP: [20.]
# Time taken for TinySQP: 1.94 seconds
# ====================
# 1
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for DS4: [20.]
# Time taken for DS4: 2.27 seconds
# ====================
# 2
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for DS5: [20.]
# Time taken for DS5: 2.55 seconds
# ====================
# 3
# Best value for ChainMetaModelDSSQP: [20.]
# Time taken for ChainMetaModelDSSQP: 3.10 seconds
# ====================
# 4
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for NgIoh16: [20.]
# Time taken for NgIoh16: 3.79 seconds
# ====================
# 5
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for NgIoh21: [20.]
# Time taken for NgIoh21: 3.49 seconds
# ====================
# 6
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for NgIoh20: [20.]
# Time taken for NgIoh20: 3.56 seconds
# ====================
# 7
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for NgIoh18: [20.]
# Time taken for NgIoh18: 3.44 seconds
# ====================
# 8
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# Best value for NgIoh10: [20.]
# Time taken for NgIoh10: 4.83 seconds
# ====================
# 9
# Best value for NgIoh8: [20.]
# Time taken for NgIoh8: 3.84 seconds
# ====================
# 10
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:202: UserWarning: COBYLA: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to 1e-06
#   warn(f'{solver}: Invalid RHOEND; it should be a positive number and RHOEND <= RHOBEG; it is set to {rhoend}')
# c:\Users\Benny\anaconda3\Lib\site-packages\scipy\_lib\pyprima\common\preproc.py:68: UserWarning: COBYLA: Invalid MAXFUN; it should be at least num_vars + 2; it is set to 5
#   warn(f'{solver}: Invalid MAXFUN; it should be at least {min_maxfun_str}; it is set to {maxfun}')
# Best value for NgIoh13b: [20.]
# Time taken for NgIoh13b: 3.43 seconds
# ====================
